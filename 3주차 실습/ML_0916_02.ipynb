# %% [markdown]
# <font color='tomato'><font color="#CC3D3D"><p>
# # 실습-02: 머신러닝 맛보기 with sklearn

# %%
import pandas as pd
import warnings; warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv('titanic_train.csv', encoding='cp949')
train
# Out:
#      승객ID  생존여부  객실등급  성별    나이  동반_형제자매배우자  동반_부모자식     티켓가격  \
# 0       1     0     3  남자  22.0           1        0   7.2500
# 1       2     1     1  여자  38.0           1        0  71.2833
# 2       3     1     3  여자  26.0           0        0   7.9250
# 3       4     1     1  여자  35.0           1        0  53.1000
# 4       5     0     3  남자  35.0           0        0   8.0500
# ..    ...   ...   ...  ..   ...         ...      ...      ...
# 886   887     0     2  남자  27.0           0        0  13.0000
# 887   888     1     1  여자  19.0           0        0  30.0000
# 888   889     0     3  여자   NaN           1        2  23.4500
# 889   890     1     1  남자  26.0           0        0  30.0000
# 890   891     0     3  남자  32.0           0        0   7.7500
#
#                                                     이름              티켓번호  \
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
#      객실번호 탑승항구
# 0     NaN    S
# 1     C85    C
# 2     NaN    S
# 3    C123    S
# 4     NaN    S
# ..    ...  ...
# 886   NaN    S
# 887   B42    S
# 888   NaN    S
# 889  C148    C
# 890   NaN    Q
#
# [891 rows x 12 columns]

# %% [markdown]
# *scikit-learn은 class(y)와 feature(X)로 데이터의 열이 구분되어야 한다.*

# %%
y_train = train.생존여부
X_train = train[['객실등급', '성별', '동반_형제자매배우자', '동반_부모자식', '티켓가격', '나이']]
X_train['나이']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: 나이, Length: 891, dtype: float64

# %% [markdown]
# *모든 feature는 숫자이어야 한다.*

# %%
X_train.성별 = X_train.성별.replace('여자', 0).replace('남자', 1)

# %%
X_train
# Out:
#      객실등급  성별  동반_형제자매배우자  동반_부모자식     티켓가격    나이
# 0       3   1           1        0   7.2500  22.0
# 1       1   0           1        0  71.2833  38.0
# 2       3   0           0        0   7.9250  26.0
# 3       1   0           1        0  53.1000  35.0
# 4       3   1           0        0   8.0500  35.0
# ..    ...  ..         ...      ...      ...   ...
# 886     2   1           0        0  13.0000  27.0
# 887     1   0           0        0  30.0000  19.0
# 888     3   0           1        2  23.4500   NaN
# 889     1   1           0        0  30.0000  26.0
# 890     3   1           0        0   7.7500  32.0
#
# [891 rows x 6 columns]

# %%
X_train['나이']=X_train['나이'].fillna(X_train['나이'].mean())
X_train
# Out:
#      객실등급  성별  동반_형제자매배우자  동반_부모자식     티켓가격         나이
# 0       3   1           1        0   7.2500  22.000000
# 1       1   0           1        0  71.2833  38.000000
# 2       3   0           0        0   7.9250  26.000000
# 3       1   0           1        0  53.1000  35.000000
# 4       3   1           0        0   8.0500  35.000000
# ..    ...  ..         ...      ...      ...        ...
# 886     2   1           0        0  13.0000  27.000000
# 887     1   0           0        0  30.0000  19.000000
# 888     3   0           1        2  23.4500  29.699118
# 889     1   1           0        0  30.0000  26.000000
# 890     3   1           0        0   7.7500  32.000000
#
# [891 rows x 6 columns]

# %% [markdown]
# #### 모형 생성 - 의사결정나무(Decision Tree)
# <img align="left" src='http://drive.google.com/uc?export=view&id=1OZmnohHM8_932fiNnokTRdC6ZQumrPeL'/>

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=0)
# 객체화 
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
X_train.columns
# Out:
# Index(['객실등급', '성별', '동반_형제자매배우자', '동반_부모자식', '티켓가격', '나이'], dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
import matplotlib_hangul
plt.figure(figsize=(25,20))
plot_tree(model, filled=True,class_names=['die','survive'],feature_names=X_train.columns)
plt.show()

# %% [markdown]
# #### 모형 평가

# %%
# 학습 데이터
model.score(X_train, y_train)
# Out:
# 0.9820426487093153

# %%
test
# Out:
#      승객ID  생존여부  객실등급  성별    나이  동반_형제자매배우자  동반_부모자식      티켓가격  \
# 0     892     0     3  남자   NaN           0        0   14.4583
# 1     893     0     3  남자   NaN           0        0    7.5500
# 2     894     0     3  남자   7.0           4        1   29.1250
# 3     895     1     1  여자   NaN           1        0  146.5208
# 4     896     1     3  여자  29.0           0        2   15.2458
# ..    ...   ...   ...  ..   ...         ...      ...       ...
# 352  1244     0     3  남자  35.0           0        0    7.0500
# 353  1245     0     3  남자  51.0           0        0    7.7500
# 354  1246     1     2  여자  27.0           1        0   13.8583
# 355  1247     0     3  남자  33.0           0        0    7.8958
# 356  1248     1     2  여자   4.0           2        1   39.0000
#
#                                                  이름                티켓번호 객실번호  \
# 0                             Yousseff, Mr. Gerious                2627  NaN
# 1                                Willey, Mr. Edward       S.O./P.P. 751  NaN
# 2                                Rice, Master. Eric              382652  NaN
# 3    Spencer, Mrs. William Augustus (Marie Eugenie)            PC 17569  B78
# 4           Touma, Mrs. Darwis (Hanne Youssef Razi)                2650  NaN
# ..                                              ...                 ...  ...
# 352                                 Asim, Mr. Adola  SOTON/O.Q. 3101310  NaN
# 353                Widegren, Mr. Carl/Charles Peter              347064  NaN
# 354                    Duran y More, Miss. Asuncion       SC/PARIS 2149  NaN
# 355                              Markun, Mr. Johann              349257  NaN
# 356                     Becker, Miss. Marion Louise              230136   F4
#
#     탑승항구
# 0      C
# 1      S
# 2      Q
# 3      C
# 4      C
# ..   ...
# 352    S
# 353    S
# 354    C
# 355    S
# 356    S
#
# [357 rows x 12 columns]

# %%
# 모형 검증: 평가 데이터
# 학습 데이터와 동일한 처리를 해야 함
test = pd.read_csv('titanic_test.csv', encoding='cp949')
y_test = test.생존여부
X_test = test[['객실등급', '성별', '동반_형제자매배우자', '동반_부모자식', '티켓가격','나이']]
X_test['나이']=X_test['나이'].fillna(X_test['나이'].mean())
X_test.성별 = X_test.성별.map({'여자':0, '남자':1})

model.score(X_test, y_test)
# Out:
# 0.9663865546218487

# %% [markdown]
# <font color='tomato'><font color="#CC3D3D"><p>
# # End
